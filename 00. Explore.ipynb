# %%
import pandas as pd
import numpy as np

# %%
# load dataset as dataframe
irrigation = pd.read_excel("00. Preps\Irrigation_DS.xlsx")

# %%
# explore data
irrigation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 68 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              30 non-null     int64
#  1   survey_date                             30 non-null     object
#  2   governorate                             30 non-null     object
#  3   district                                30 non-null     object
#  4   village_name                            30 non-null     object
#  5   beneficiary_name                        30 non-null     object
#  6   respondent_name                         30 non-null     object
#  7   irrigation_system_type                  30 non-null     object
#  8   crop_type                               30 non-null     object
#  9   land_prep_section_header                30 non-null     object
# ...

# %%
irrigation.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'survey_date',
#  'governorate',
#  'district',
#  'village_name',
#  'beneficiary_name',
#  'respondent_name',
#  'irrigation_system_type',
#  'crop_type',
#  'land_prep_section_header',
#  'land_prep_plowing_cost_per_acre',
#  'land_prep_settlement_cost_per_acre',
#  'land_prep_division_cost_per_acre',
#  'land_prep_terracing_cost_per_acre',
#  'land_prep_total_cost',
#  'land_prep_workers_count',
#  'land_prep_worker_wage_per_day',
#  'land_prep_working_days',
#  'land_prep_labor_total_cost',
#  'land_prep_grand_total_cost',
#  'nursery_prep_section_header',
#  'nursery_prep_total_cost',
#  'cultivation_section_header',
#  'cultivation_laborers_count',
#  'cultivation_seeds_quantity',
#  'cultivation_worker_wage_per_day',
#  'cultivation_labor_total_cost',
#  'fertilization_section_header',
#  'fertilizer_quantity_kg',
#  'fertilizer_cost_yer',
#  'fertilizer_total_cost',
#  'production_section_header',
#  'production_quantity_baskets_kg',
# ...

# %%
irrigation.head(5)
# Out:
#    Unnamed: 0 survey_date governorate district  village_name  \
# 0           0  2020-01-07        Lahj    Tuban  كدمه عوض علي
# 1           1  2020-01-27        Lahj    Tuban       بئر فضل
# 2           2  2020-01-08        Lahj    Tuban        كوكبان
# 3           3  2020-01-08        Lahj    Tuban     هران ديان
# 4           4  2020-01-08        Lahj    Tuban       الحمراء
#
#               beneficiary_name      respondent_name irrigation_system_type  \
# 0               نبيل قائد معين       نبيل قائد معين            Traditional
# 1        مختار حيدره علي حيدره       محسن علي حيدره                   Drip
# 2          صادق محمد فضل العسر  صادق محمد فضل العسر            Traditional
# 3          قيصر سبيت ناصر سبيت  قيصر سبيت ناصر سبيت                   Drip
# 4  ارسلان عبدالله ناصر حيدرة\n  ارسلان عبدالله ناصر                   Drip
#
#   crop_type land_prep_section_header  ...  water_working_days_per_month  \
# ...

# %%
# Display current columns
print("=" * 60)
print("CURRENT COLUMN NAMES:")
print("=" * 60)
for i, col in enumerate(irrigation.columns, 1):
    print(f"{i}. {col}")

print(f"\nTotal columns: {len(irrigation.columns)}")
print(f"Total rows: {len(irrigation)}")

# Display first few rows to understand data
print("\n" + "=" * 60)
print("FIRST 3 ROWS OF DATA:")
print("=" * 60)
print(irrigation.head(3))

# Show data types
print("\n" + "=" * 60)
print("COLUMN DATA TYPES:")
print("=" * 60)
print(irrigation.dtypes)
# Out:
# ...
# CURRENT COLUMN NAMES:
# ...
# 1. Unnamed: 0
# 2. survey_date
# 3. governorate
# 4. district
# 5. village_name
# 6. beneficiary_name
# 7. respondent_name
# 8. irrigation_system_type
# 9. crop_type
# 10. land_prep_section_header
# 11. land_prep_plowing_cost_per_acre
# 12. land_prep_settlement_cost_per_acre
# 13. land_prep_division_cost_per_acre
# 14. land_prep_terracing_cost_per_acre
# 15. land_prep_total_cost
# 16. land_prep_workers_count
# 17. land_prep_worker_wage_per_day
# 18. land_prep_working_days
# 19. land_prep_labor_total_cost
# 20. land_prep_grand_total_cost
# 21. nursery_prep_section_header
# 22. nursery_prep_total_cost
# 23. cultivation_section_header
# 24. cultivation_laborers_count
# 25. cultivation_seeds_quantity
# 26. cultivation_worker_wage_per_day
# 27. cultivation_labor_total_cost
# 28. fertilization_section_header
# 29. fertilizer_quantity_kg
# 30. fertilizer_cost_yer
# 31. fertilizer_total_cost
# 32. production_section_header
# 33. production_quantity_baskets_kg
# ...
